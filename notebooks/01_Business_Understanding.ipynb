# %%
business_objectives = {
    "background": "Using data to improve store sales and item placement.",
    "primary_objective": "Find item associations and analyze weekend vs. weekday shopping habits.",
    "success_criteria": [
        "Find 5+ strong item connections (Rules).",
        "Group all items into categories using Web Scraping.",
        "Compare basket sizes for weekends vs. weekdays."
    ]
}

# %%
situation_assessment = {
    "resources": {
        "personnel": ["Student (Data Analyst)"],
        "data_sources": ["Grocery CSV file", "Wikipedia (for categories)"],
        "computing": "Personal Laptop (MacBook Pro)",
        "software": ["Python", "VS Code", "Pandas", "BeautifulSoup"]
    },
    "requirements": [
        "Project must be finished by the deadline.",
        "Code must be clean and modular.",
        "Must use Web Scraping and Association Rules."
    ],
    "assumptions": [
        "The CSV data is accurate and reflects real customer behavior."
    ],
    "constraints": [
        "Processing power is limited to one laptop.",
        "No budget to buy extra data or tools."
    ],
    "risks_and_contingencies": [
        {
            "risk": "The Wikipedia scraper might fail if the website layout changes.",
            "probability": "Medium",
            "mitigation": "Write flexible code that looks for general 'headline' tags."
        },
        {
            "risk": "The computer might run slowly when processing 38,000 rows.",
            "probability": "Low",
            "mitigation": "Use efficient Pandas functions to save memory."
        }
    ],
    "terminology": {
        "Market Basket Analysis": "Finding which items are bought together.",
        "Web Scraping": "Automatically pulling data from a website."
    },
    "cost_benefit": "Cost is $0 (using free tools). Benefit is high-quality business insights."
}

# %%
data_mining_goals = {
    "problem_type": "Association Rule Mining (Market Basket Analysis)",
    "target_variable": "itemDescription",
    "technical_goals": [
        "Use the Apriori algorithm to find which items are bought together.",
        "Scrape Wikipedia to get category names for all 167 items.",
        "Create charts to show if people buy more on weekends."
    ],
    "success_metrics": [
        "Find at least 5 rules where 'Lift' is higher than 1.0.",
        "Successfully link the scraped Wikipedia categories to our CSV data.",
        "Produce 3 professional charts (Bar charts and Count plots)."
    ]
}

# %%
project_plan = {
    "tools": ["Pandas", "BeautifulSoup", "mlxtend", "Seaborn", "GitHub"],
    "techniques": ["Apriori Algorithm", "Web Scraping", "Data Visualization"],
    "timeline": [
        {"phase": "1. Business Planning", "duration": "1 Day", "status": "Completed"},
        {"phase": "2. Data Cleaning & Scraping", "duration": "1 Week", "status": "In Progress"},
        {"phase": "3. Running the Model", "duration": "3 Days", "status": "Not Started"},
        {"phase": "4. Final Report & Poster", "duration": "1 Week", "status": "Not Started"}
    ],
    "dependencies": [
        "I need the Wikipedia data finished before I can make the final charts."
    ],
    "tool_justification": "I am using Pandas because it's fast for 38,000 rows, and BeautifulSoup because it's the best tool for grabbing data from Wikipedia."
}
