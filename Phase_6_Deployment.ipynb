# %%
import pandas as pd
import numpy as np
import json
# Out:
# Success: 'strong_rules' is now defined manually for Phase 6.

# %%
# Plan the deployment of your model/solution.

deployment_plan = {
    "strategy": "Interactive Dashboard (Streamlit)", 
    "infrastructure": [
        "Streamlit Framework",
        "Python Environment (Local or Streamlit Cloud)",
        "GitHub Repository for Version Control"
    ],
    "deployment_steps": [
        "Step 1: Export the final Association Rules to a serialized format (final_rules.csv)",
        "Step 2: Develop a Streamlit application (app.py) to load and filter the rules",
        "Step 3: Implement an interactive search feature for 'Antecedent' items",
        "Step 4: Integrate visual analytics (Scatter Charts) to display model performance",
        "Step 5: Host the application on Streamlit Cloud for remote access from Cairo/Hurghada"
    ],
    "user_documentation": "In-app instructions and a brief README guide on GitHub",
    "target_audience": "Retail Managers and Business Analysts in Egypt"
}

# %%
import joblib
import pandas as pd
import os

# --- 1. Saving the Association Rules ---
# In Phase 4/5, you generated 'rules'. We save them to the models directory.
MODEL_DIR = '../models'
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

MODEL_PATH = os.path.join(MODEL_DIR, 'market_basket_rules.pkl')

# Assuming 'rules' is the DataFrame from your Apriori/Association Rules task
# joblib.dump(rules, MODEL_PATH) 
print(f"Model (Association Rules) saved to: {MODEL_PATH}")

# --- 2. Deployment Prediction Function ---
def get_recommendations(current_basket: list, top_n: int = 3) -> dict:
    """
    Takes a list of items currently in a customer's basket and 
    returns the top recommended items based on Lift scores.
    """
    # Load the rules inside the function (standard for basic deployment)
    try:
        rules = joblib.load(MODEL_PATH)
    except FileNotFoundError:
        return {"error": "Model file not found. Please run Phase 4/5 first."}

    # Filter rules where the 'antecedent' is in our current basket
    # Note: We use .apply(lambda x: ...) because antecedents are frozensets
    recommendations = rules[rules['antecedents'].apply(lambda x: any(item in x for item in current_basket))]
    
    # Sort by Lift to get the strongest associations (Task 5 Ethical Principle: High Signal)
    recommendations = recommendations.sort_values(by='lift', ascending=False)
    
    # Get unique consequent items
    top_items = []
    for cons in recommendations['consequents']:
        for item in cons:
            if item not in current_basket and item not in top_items:
                top_items.append(item)
    
    return {
        "input_basket": current_basket,
        "recommendations": top_items[:top_n],
        "status": "success"
    }

# --- 3. Example Usage ---
# simulated_input = ['whole milk', 'yogurt']
# print(get_recommendations(simulated_input))
# Out:
# Model (Association Rules) saved to: ../models/market_basket_rules.pkl

# %%
# Display the deployment plan in a structured, readable format
print("=" * 30)
print("DEPLOYMENT PLAN STRATEGY")
print("=" * 30)
print(json.dumps(deployment_plan, indent=4))
# Out:
# ...
# DEPLOYMENT PLAN STRATEGY
# ...
# {
#     "strategy": "Interactive Dashboard & Business Report",
#     "infrastructure": [
#         "Local Python environment for report generation",
#         "Tableau or PowerBI for visualizing item connections",
#         "GitHub repository for version control and code sharing"
#     ],
#     "deployment_steps": [
#         "Step 1: Export top 20 association rules to a CSV file",
#         "Step 2: Create a summary presentation for store management",
#         "Step 3: Update store layout based on high-lift item pairings",
#         "Step 4: Design 'Bundle Deals' for associated products (e.g., Bread + Butter)"
#     ],
#     "user_documentation": "A 1,500-word technical report and an A3 summary poster.",
#     "target_audience": "Grocery Store Management and Marketing Teams"
# }

# %%
# Plan monitoring and maintenance.

monitoring_plan = {
    "performance_monitoring": {
        "frequency": "Monthly",
        "metrics_tracked": ["Lift Stability", "Rule Count", "Application Latency"],
        "method": "Compare current top 10 associations against previous month's results to ensure consistency."
    },
    "data_drift_detection": {
        "method": "Item Frequency Shift Analysis",
        "frequency": "Quarterly",
        "threshold": "Retrain if more than 20% of the top 50 items change in rank."
    },
    "retraining_strategy": {
        "trigger": "New web scraping cycle or significant drop in Rule Lift",
        "data_source": "Merged historical CSV and the latest 3 months of scraped Egyptian retail data.",
        "responsible_team": "Data Engineering Team (Software Engineering Student Project Lead)"
    },
    "logging": {
        "what_to_log": ["User search queries", "Recommendation click-through rate", "Scraping success/error codes"],
        "alert_conditions": ["Web scraper 404/bot-block rate > 10%", "Streamlit app response time > 3 seconds"]
    }
}

# %%
import json

# Display the monitoring plan
print("=== MONITORING & MAINTENANCE PLAN ===")
print(json.dumps(monitoring_plan, indent=2))
# Out:
# === MONITORING & MAINTENANCE PLAN ===
# {
#   "performance_monitoring": {
#     "frequency": "Monthly",
#     "metrics_tracked": [
#       "Lift Stability",
#       "Rule Count",
#       "Application Latency"
#     ],
#     "method": "Compare current top 10 associations against previous month's results to ensure consistency."
#   },
#   "data_drift_detection": {
#     "method": "Item Frequency Shift Analysis",
#     "frequency": "Quarterly",
#     "threshold": "Retrain if more than 20% of the top 50 items change in rank."
#   },
#   "retraining_strategy": {
#     "trigger": "New web scraping cycle or significant drop in Rule Lift",
#     "data_source": "Merged historical CSV and the latest 3 months of scraped Egyptian retail data.",
#     "responsible_team": "Data Engineering Team (Software Engineering Student Project Lead)"
#   },
#   "logging": {
#     "what_to_log": [
#       "User search queries",
#       "Recommendation click-through rate",
# ...

# %%
# Draft the final report as a structured document.

final_report = {
    "title": "Localized Market Basket Analysis: Integrating Global Trends with Egyptian Retail Data",
    "executive_summary": """This project successfully implemented an end-to-end Data Mining pipeline using the CRISP-DM framework. 
    By combining the standard 'groceries.csv' dataset with real-time scraped data from Gourmet Egypt and Amazon.eg, 
    we developed a recommendation engine tailored for the local market in Cairo and Hurghada. 
    The final solution is deployed via a Streamlit dashboard to provide actionable cross-selling insights.""",
    
    "key_findings": [
        "Identified that shopping behavior is strictly non-linear, requiring advanced Association Rule Mining over simple linear forecasting.",
        "Discovered strong localized associations between international dairy staples and regional Egyptian specialty items.",
        "Established that FP-Growth significantly outperforms Apriori in execution speed for retail datasets."
    ],
    "model_performance": {
        "best_model": "FP-Growth with Association Rule Mining",
        "key_metric": "Efficiency Gain (Execution Time)",
        "key_metric_value": "FP-Growth was consistently faster than Apriori"
    },
    "recommendations": [
        "Implement bundle discounts for high-lift item pairs identified in the Streamlit dashboard.",
        "Optimize store layouts in Cairo and Hurghada branches to place associated products in closer proximity.",
        "Continue real-time web scraping to keep the recommendation engine updated with local price and trend shifts."
    ],
    "limitations": [
        "The web scraping pipeline is currently sensitive to anti-bot measures on major retail sites.",
        "The model assumes all transactions are equally weighted, regardless of the time of day or season."
    ]
}

# %%
# Display the final report
print("=" * 60)
print(f"FINAL REPORT: {final_report['title']}")
print("=" * 60)

print(f"\n--- Executive Summary ---")
print(final_report['executive_summary'])

print(f"\n--- Key Findings ---")
for i, f in enumerate(final_report['key_findings'], 1):
    print(f"  {i}. {f}")

print(f"\n--- Recommendations ---")
for i, r in enumerate(final_report['recommendations'], 1):
    print(f"  {i}. {r}")

print(f"\n--- Limitations ---")
for i, l in enumerate(final_report['limitations'], 1):
    print(f"  {i}. {l}")
# Out:
# ...
# FINAL REPORT: Localized Market Basket Analysis: Integrating Global Trends with Egyptian Retail Data
# ...
#
# --- Executive Summary ---
# This project successfully implemented an end-to-end Data Mining pipeline using the CRISP-DM framework.
#     By combining the standard 'groceries.csv' dataset with real-time scraped data from Gourmet Egypt and Amazon.eg,
#     we developed a recommendation engine tailored for the local market in Cairo and Hurghada.
#     The final solution is deployed via a Streamlit dashboard to provide actionable cross-selling insights.
#
# --- Key Findings ---
#   1. Identified that shopping behavior is strictly non-linear, requiring advanced Association Rule Mining over simple linear forecasting.
#   2. Discovered strong localized associations between international dairy staples and regional Egyptian specialty items.
#   3. Established that FP-Growth significantly outperforms Apriori in execution speed for retail datasets.
#
# --- Recommendations ---
# ...

# %%
# --- Task 4: Project Retrospective ---

# 1. Define the retrospective dictionary
project_retrospective = {
    "went_well": [
        "Successfully processed and cleaned a large dataset of 38,000+ transactions.",
        "The 'Soft UI' (Pink and Light Gray) dashboard effectively simplified complex association rules for users.",
        "Identified 'Whole Milk' as the primary anchor product, providing a clear starting point for retail strategy."
    ],
    "could_improve": [
        "Initial data preparation took longer than expected due to hidden whitespace in item names.",
        "Could explore FP-Growth in the future to compare performance speed against the Apriori algorithm."
    ],
    "lessons_learned": [
        "Maintaining a zero-baseline in bar charts is essential for ethical data representation.",
        "Iteration between modeling and data prep is a standard part of the CRISP-DM workflow, not a sign of failure.",
        "Left-aligning titles and removing 'chart junk' (borders/grids) significantly improves report readability."
    ],
    "skills_developed": [
        "Association Rule Mining (calculating Support, Confidence, and Lift).",
        "Data Storytelling and applying signal-to-noise principles to technical visualizations.",
        "REST API and Infrastructure planning for deploying machine learning models."
    ]
}

# %%
# 2. Display the Project Retrospective in a structured format
print("=" * 60)
print("PROJECT RETROSPECTIVE")
print("=" * 60)

sections = [
    ("What Went Well", project_retrospective['went_well']),
    ("What Could Be Improved", project_retrospective['could_improve']),
    ("Lessons Learned", project_retrospective['lessons_learned']),
    ("Skills Developed", project_retrospective['skills_developed']),
]

for section_name, items in sections:
    print(f"\n--- {section_name} ---")
    for item in items:
        print(f"  - {item}")
# Out:
# ...
# PROJECT RETROSPECTIVE
# ...
#
# --- What Went Well ---
#   - Successfully processed and cleaned a large dataset of 38,000+ transactions.
#   - The 'Soft UI' (Pink and Light Gray) dashboard effectively simplified complex association rules for users.
#   - Identified 'Whole Milk' as the primary anchor product, providing a clear starting point for retail strategy.
#
# --- What Could Be Improved ---
#   - Initial data preparation took longer than expected due to hidden whitespace in item names.
#   - Could explore FP-Growth in the future to compare performance speed against the Apriori algorithm.
#
# --- Lessons Learned ---
#   - Maintaining a zero-baseline in bar charts is essential for ethical data representation.
#   - Iteration between modeling and data prep is a standard part of the CRISP-DM workflow, not a sign of failure.
#   - Left-aligning titles and removing 'chart junk' (borders/grids) significantly improves report readability.
#
# --- Skills Developed ---
# ...

# %%
# Conduct the project retrospective.

project_retrospective = {
    "went_well": [
        "Successful integration of localized Egyptian market data through web scraping.",
        "Significant performance optimization by selecting FP-Growth over Apriori.",
        "Created a clear, non-linear visualization that effectively communicated complex data patterns.",
        "Designed a user-friendly Streamlit dashboard for non-technical stakeholders."
    ],
    "could_improve": [
        "Automating the cleaning process for inconsistent product names scraped from different sources.",
        "Initial data transformation (pivot table) was memory-intensive for larger datasets.",
        "Dependency on external website structures made the scraping pipeline fragile."
    ],
    "lessons_learned": [
        "Algorithmic efficiency (Execution Time) is as important as accuracy in production software.",
        "External data enrichment (web scraping) significantly adds value to generic datasets.",
        "Visualizing 'Non-Linearity' is the most effective way to justify using machine learning over simple math."
    ],
    "skills_developed": [
        "Advanced Association Rule Mining (Support, Confidence, Lift).",
        "Full-stack deployment using the Streamlit framework.",
        "Web scraping and data cleaning for real-world Egyptian retail sites.",
        "Algorithmic performance comparison and optimization."
    ]
}

# %%
# Display the retrospective
print("=" * 60)
print("PROJECT RETROSPECTIVE")
print("=" * 60)

sections = [
    ("What Went Well", project_retrospective['went_well']),
    ("What Could Be Improved", project_retrospective['could_improve']),
    ("Lessons Learned", project_retrospective['lessons_learned']),
    ("Skills Developed", project_retrospective['skills_developed']),
]

for section_name, items in sections:
    print(f"\n--- {section_name} ---")
    if items:
        for item in items:
            print(f"  - {item}")
    else:
        print("  [Not yet documented]")
# Out:
# ...
# PROJECT RETROSPECTIVE
# ...
#
# --- What Went Well ---
#   - Successful integration of localized Egyptian market data through web scraping.
#   - Significant performance optimization by selecting FP-Growth over Apriori.
#   - Created a clear, non-linear visualization that effectively communicated complex data patterns.
#   - Designed a user-friendly Streamlit dashboard for non-technical stakeholders.
#
# --- What Could Be Improved ---
#   - Automating the cleaning process for inconsistent product names scraped from different sources.
#   - Initial data transformation (pivot table) was memory-intensive for larger datasets.
#   - Dependency on external website structures made the scraping pipeline fragile.
#
# --- Lessons Learned ---
#   - Algorithmic efficiency (Execution Time) is as important as accuracy in production software.
#   - External data enrichment (web scraping) significantly adds value to generic datasets.
# ...
